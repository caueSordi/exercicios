# %% [markdown]
# ## Exercicio 1

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import time

tempo = [0,0,0,0]

n = [10**5,10**6,10**7,10**8]

for i in range (len(n)):
  start = time.time()
  a_vetor = np.random.rand(n[i])
  b_vetor = np.random.rand(n[i])
  alpha = np.random.randint(100)
  beta = np.random.randint(100)
  c_vetor = alpha * a_vetor + beta * b_vetor
  end = time.time()
  tempo[i] = end - start
  print(f"n: {n[i]}")
  print(f"Time: {end - start}")
  print("\n \n \n")

plt.plot(n, tempo)
plt.xlabel('n')
plt.ylabel('tempo')
plt.show()
# Out:
# n: 100000
# Time: 0.27282142639160156
#
#
#
#
# n: 1000000
# Time: 0.014217853546142578
#
#
#
#
# n: 10000000
# Time: 0.2230541706085205
#
#
#
#
# n: 100000000
# Time: 4.764655351638794

# %%
import numpy as np
import matplotlib.pyplot as plt

# Valores iniciais
initial_x = 0.1
n_vai = 5000

# Valores A
a_values = [1, 2, 3.8, 4]

# Variações
variances = []

# Iterar sobre os valores de a
for a in a_values:
  # Inicializar x
  x = np.zeros(n_vai)
  x[0] = initial_x

  # Calcular os valores de x
  for i in range(1, n_vai):
    x[i] = a * x[i-1] * (1 - x[i-1])

  # faz a variação
  variance = np.var(x)

  #salva
  variances.append(variance)

# Plotar variações em função de a_values
plt.plot(a_values, variances, 'o-', linestyle='-')

# Adicionar título e rótulos
plt.title("Variação em função de a")
plt.xlabel("valores de a")
plt.ylabel("Variação")

# Mostrar o gráfico
plt.show()
# Out:
# /tmp/ipykernel_8725/3884201336.py:31: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(a_values, variances, 'o-', linestyle='-')

# %% [markdown]
# ## Exercicio 2

# %%
initial_x = 0.1
n_vai = 5000

a_values = [1, 2, 3.8, 4]

variances = []
for a in a_values:
  # vai lá e pega os valores de a
  x = np.zeros(n_vai)
  x[0] = initial_x

  # faz todas as somatorias
  for i in range(1, n_vai):
    x[i] = a * x[i-1] * (1 - x[i-1])
    #print(x[i])

  # calcula variação (GRAÇAS A DEUS TEM UMA FUNÇÃO PRA ISSO)
  variance = np.var(x)
  print(f"variação para a = {a}:", variance)
  # salva a variação (pra depois fazer a média
  variances.append(variance)
  

# Imprime vai lá e imprime os valores
variacao_media = np.median(variances)
print("variação média:")
print(variacao_media)
# Out:
# variação para a = 1: 1.8439281581673696e-05
# variação para a = 2: 6.227375439911989e-05
# variação para a = 3.8: 0.061046901046755656
# variação para a = 4: 0.12441782441652699
# variação média:
# 0.03055458740057739

# %% [markdown]
# ## Exercicio 3

# %%
for a in a_values:
    x = np.zeros(n_vai)
    x[0] = initial_x

    for i in range(1, n_vai):
        x[i] = a * x[i-1] * (1 - x[i-1])

    plt.plot(range(n_vai), x, label=f'a = {a}', color=(random.random(), random.random(), random.random()))
    plt.xlabel('n_vai')
    plt.ylabel('x')
    plt.legend()
    plt.show()

# %% [markdown]
# ## Exercicio 4

# %%
plt.figure(figsize=(10, 6))
for i in range(n):
    a = a_min + da * i
    x = X[i]
    plt.plot([a] * len(x), x, '.', markersize=0.05, color='blue')

plt.xlabel('a')
plt.ylabel('x')
plt.title('Bifurcation Diagram')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 6
#       3 X = []  # Replace [] with the appropriate list of values
#       5 plt.figure(figsize=(10, 6))
# ----> 6 for i in range(n):
#       7     a = a_min + da * i
#       8     x = X[i]
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
import numpy as np
import matplotlib.pyplot as plt

# Valores iniciais
X = []
initial_x = 0.6
r_min = 1
r_max = 4
dr = 0.001
n = int((r_max - r_min) / dr)

# Iterar sobre os valores de r
for r in np.arange(r_min, r_max, dr):
    x = [initial_x]
    for i in range(1, 5000):
        next_x = r * x[-1] * (1 - x[-1])
        x.append(next_x)
    X.append(x[100:])

# pega os valores de r e x e plota
plt.figure(figsize=(10, 6))
for i in range(n):
    r = r_min + dr * i
    x = X[i]
    plt.plot([r] * len(x), x, '.', markersize=0.05, color='blue')

plt.xlabel('A')
plt.ylabel('X')
plt.title('diagrama de bifurcação')
plt.show()

# %% [markdown]
# ## Exercicio 5
